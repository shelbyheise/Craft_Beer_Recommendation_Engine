# %%
import pandas as pd
import numpy as np
from sklearn.metrics import jaccard_score
from scipy.spatial.distance import pdist, squareform

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# Data for this project can be found here: https://www.kaggle.com/nickhould/craft-cans?select=beers.csv

# %%
#Read saved dataset 
df = pd.read_csv('beer_data.csv', na_values=['none'])

# %%
df.head()
# Out:
#    Unnamed: 0    abv    id            beer_name  \
# 0           0  0.050  1436             Pub Beer
# 1           1  0.066  2265          Devil's Cup
# 2           2  0.071  2264  Rise of the Phoenix
# 3           3  0.090  2263             Sinister
# 4           4  0.075  2262        Sex and Candy
#
#                        beer_style  brewery_id  ounces  \
# 0             American Pale Lager         408    12.0
# 1         American Pale Ale (APA)         177    12.0
# 2                    American IPA         177    12.0
# 3  American Double / Imperial IPA         177    12.0
# 4                    American IPA         177    12.0
#
#                 brewery_name  city state
# 0  10 Barrel Brewing Company  Bend    OR
# 1        18th Street Brewery  Gary    IN
# 2        18th Street Brewery  Gary    IN
# 3        18th Street Brewery  Gary    IN
# 4        18th Street Brewery  Gary    IN

# %%
df = df.drop(columns='Unnamed: 0')

#For this test, checking on Texas beers
df_tx = df.loc[df.state == ' TX']

#Creating column to be used as index
df_tx['beer_info'] = df_tx['beer_name']
df_tx = df_tx.set_index('beer_info')

#Converting everything to string for concat
df_tx = df_tx.astype(str)

#Create description column
df_tx['description'] = df_tx['abv'] + ' ' + df_tx['beer_style'] + ' ' + df_tx['brewery_name'] + ' ' + df_tx['city']
# Out:
# <ipython-input-22-b45403ae1a49>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tx['beer_info'] = df_tx['beer_name']

# %%
df_tx.head()
# Out:
#                                              abv    id  \
# beer_info
# Quakertown Stout                           0.092  1333
# Greenbelt Farmhouse Ale                    0.051  1332
# Heavy Machinery IPA Series #1: Heavy Fist   0.07  1409
# Fire Eagle IPA                             0.062   343
# Peacemaker                                 0.051   342
#
#                                                                            beer_name  \
# beer_info
# Quakertown Stout                                                    Quakertown Stout
# Greenbelt Farmhouse Ale                                      Greenbelt Farmhouse Ale
# Heavy Machinery IPA Series #1: Heavy Fist  Heavy Machinery IPA Series #1: Heavy Fist
# Fire Eagle IPA                                                        Fire Eagle IPA
# Peacemaker                                                                Peacemaker
#
#                                                                  beer_style  \
# beer_info
# Quakertown Stout                           American Double / Imperial Stout
# Greenbelt Farmhouse Ale                              Saison / Farmhouse Ale
# Heavy Machinery IPA Series #1: Heavy Fist                American Black Ale
# Fire Eagle IPA                                                 American IPA
# Peacemaker                                          American Pale Ale (APA)
#
#                                           brewery_id ounces  \
# beer_info
# Quakertown Stout                                 426   12.0
# Greenbelt Farmhouse Ale                          426   12.0
# Heavy Machinery IPA Series #1: Heavy Fist        413   16.0
# Fire Eagle IPA                                   413   12.0
# Peacemaker                                       413   12.0
#
#                                                   brewery_name    city state  \
# beer_info
# Quakertown Stout                           Armadillo Ale Works  Denton    TX
# Greenbelt Farmhouse Ale                    Armadillo Ale Works  Denton    TX
# Heavy Machinery IPA Series #1: Heavy Fist     Austin Beerworks  Austin    TX
# Fire Eagle IPA                                Austin Beerworks  Austin    TX
# Peacemaker                                    Austin Beerworks  Austin    TX
#
#                                                                                  description
# beer_info
# Quakertown Stout                           0.092 American Double / Imperial Stout Armadil...
# Greenbelt Farmhouse Ale                    0.051 Saison / Farmhouse Ale Armadillo Ale Wor...
# Heavy Machinery IPA Series #1: Heavy Fist    0.07 American Black Ale Austin Beerworks Austin
# Fire Eagle IPA                                    0.062 American IPA Austin Beerworks Austin
# Peacemaker                                 0.051 American Pale Ale (APA) Austin Beerworks...

# %%
#Dropping everything but beer_name and description for next step
df_tx_vect = df_tx[['beer_name', 'description']]

df_tx_vect = df_tx_vect.reset_index(drop = True)

# %%
#Set up vectorizer
tfidfvec = TfidfVectorizer(min_df=2, max_df=0.8)

# %%
#Apply and convert to array
vectorized_df = tfidfvec.fit_transform(df_tx_vect.description)

vectorized_df = vectorized_df.toarray()

# %%
#Create dataframe and re-set index
tfidf_df = pd.DataFrame(vectorized_df, columns=tfidfvec.get_feature_names())

tfidf_df.index = df_tx_vect['beer_name']

# %%
tfidf_df.head()
# Out:
#                                            042  044000000000000004  046  047  \
# beer_name
# Quakertown Stout                           0.0                 0.0  0.0  0.0
# Greenbelt Farmhouse Ale                    0.0                 0.0  0.0  0.0
# Heavy Machinery IPA Series #1: Heavy Fist  0.0                 0.0  0.0  0.0
# Fire Eagle IPA                             0.0                 0.0  0.0  0.0
# Peacemaker                                 0.0                 0.0  0.0  0.0
#
#                                            048  049   05       051  \
# beer_name
# Quakertown Stout                           0.0  0.0  0.0  0.000000
# Greenbelt Farmhouse Ale                    0.0  0.0  0.0  0.319097
# Heavy Machinery IPA Series #1: Heavy Fist  0.0  0.0  0.0  0.000000
# Fire Eagle IPA                             0.0  0.0  0.0  0.000000
# Peacemaker                                 0.0  0.0  0.0  0.398000
#
#                                            052000000000000005  053  ...  \
# beer_name                                                           ...
# Quakertown Stout                                          0.0  0.0  ...
# Greenbelt Farmhouse Ale                                   0.0  0.0  ...
# Heavy Machinery IPA Series #1: Heavy Fist                 0.0  0.0  ...
# Fire Eagle IPA                                            0.0  0.0  ...
# Peacemaker                                                0.0  0.0  ...
#
#                                            station     stout  texas  texian  \
# beer_name
# Quakertown Stout                               0.0  0.349532    0.0     0.0
# Greenbelt Farmhouse Ale                        0.0  0.000000    0.0     0.0
# Heavy Machinery IPA Series #1: Heavy Fist      0.0  0.000000    0.0     0.0
# Fire Eagle IPA                                 0.0  0.000000    0.0     0.0
# Peacemaker                                     0.0  0.000000    0.0     0.0
#
#                                            twisted  uncle  wheat  witbier  \
# beer_name
# Quakertown Stout                               0.0    0.0    0.0      0.0
# Greenbelt Farmhouse Ale                        0.0    0.0    0.0      0.0
# Heavy Machinery IPA Series #1: Heavy Fist      0.0    0.0    0.0      0.0
# Fire Eagle IPA                                 0.0    0.0    0.0      0.0
# Peacemaker                                     0.0    0.0    0.0      0.0
#
#                                               works  worth
# beer_name
# Quakertown Stout                           0.408864    0.0
# Greenbelt Farmhouse Ale                    0.438326    0.0
# Heavy Machinery IPA Series #1: Heavy Fist  0.000000    0.0
# Fire Eagle IPA                             0.000000    0.0
# Peacemaker                                 0.000000    0.0
#
# [5 rows x 129 columns]

# %%
#Set up cosine similarity on tfidf dataframe
cosine_similarity_array = cosine_similarity(tfidf_df)

# %%
cosine_sim_df = pd.DataFrame(cosine_similarity_array, index=tfidf_df.index, columns=tfidf_df.index)

# %%
cosine_sim_df.head()
# Out:
# beer_name                                  Quakertown Stout  \
# beer_name
# Quakertown Stout                                   1.000000
# Greenbelt Farmhouse Ale                            0.587470
# Heavy Machinery IPA Series #1: Heavy Fist          0.051601
# Fire Eagle IPA                                     0.028643
# Peacemaker                                         0.054441
#
# beer_name                                  Greenbelt Farmhouse Ale  \
# beer_name
# Quakertown Stout                                          0.587470
# Greenbelt Farmhouse Ale                                   1.000000
# Heavy Machinery IPA Series #1: Heavy Fist                 0.063145
# Fire Eagle IPA                                            0.000000
# Peacemaker                                                0.193621
#
# beer_name                                  Heavy Machinery IPA Series #1: Heavy Fist  \
# beer_name
# Quakertown Stout                                                            0.051601
# Greenbelt Farmhouse Ale                                                     0.063145
# Heavy Machinery IPA Series #1: Heavy Fist                                   1.000000
# Fire Eagle IPA                                                              0.662641
# Peacemaker                                                                  0.580038
#
# beer_name                                  Fire Eagle IPA  Peacemaker  \
# beer_name
# Quakertown Stout                                 0.028643    0.054441
# Greenbelt Farmhouse Ale                          0.000000    0.193621
# Heavy Machinery IPA Series #1: Heavy Fist        0.662641    0.580038
# Fire Eagle IPA                                   1.000000    0.699116
# Peacemaker                                       0.699116    1.000000
#
# beer_name                                  Pearl-Snap  Black Thunder  \
# beer_name
# Quakertown Stout                             0.000000       0.000000
# Greenbelt Farmhouse Ale                      0.000000       0.000000
# Heavy Machinery IPA Series #1: Heavy Fist    0.450723       0.598983
# Fire Eagle IPA                               0.582821       0.774533
# Peacemaker                                   0.475532       0.631954
#
# beer_name                                  La Frontera Premium IPA  \
# beer_name
# Quakertown Stout                                          0.025752
# Greenbelt Farmhouse Ale                                   0.000000
# Heavy Machinery IPA Series #1: Heavy Fist                 0.032638
# Fire Eagle IPA                                            0.170908
# Peacemaker                                                0.034434
#
# beer_name                                  Tejas Lager  Number 22 Porter  ...  \
# beer_name                                                                 ...
# Quakertown Stout                                   0.0          0.024019  ...
# Greenbelt Farmhouse Ale                            0.0          0.000000  ...
# Heavy Machinery IPA Series #1: Heavy Fist          0.0          0.030441  ...
# Fire Eagle IPA                                     0.0          0.039363  ...
# Peacemaker                                         0.0          0.032117  ...
#
# beer_name                                  Bombshell Blonde  First Stand  \
# beer_name
# Quakertown Stout                                   0.059602     0.027486
# Greenbelt Farmhouse Ale                            0.072936     0.296116
# Heavy Machinery IPA Series #1: Heavy Fist          0.075539     0.034836
# Fire Eagle IPA                                     0.041930     0.000000
# Peacemaker                                         0.079697     0.036753
#
# beer_name                                  Battle LIne  Broken Bridge  \
# beer_name
# Quakertown Stout                              0.053234            0.0
# Greenbelt Farmhouse Ale                       0.065143            0.0
# Heavy Machinery IPA Series #1: Heavy Fist     0.067468            0.0
# Fire Eagle IPA                                0.037450            0.0
# Peacemaker                                    0.071182            0.0
#
# beer_name                                    Brutus  Cow Creek  Chupahopra  \
# beer_name
# Quakertown Stout                           0.028336   0.019910    0.020827
# Greenbelt Farmhouse Ale                    0.060756   0.000000    0.000000
# Heavy Machinery IPA Series #1: Heavy Fist  0.035913   0.025234    0.026396
# Fire Eagle IPA                             0.106519   0.032630    0.138225
# Peacemaker                                 0.122190   0.026623    0.027849
#
# beer_name                                  Twisted X  The Green Room  \
# beer_name
# Quakertown Stout                            0.021499        0.018040
# Greenbelt Farmhouse Ale                     0.116831        0.000000
# Heavy Machinery IPA Series #1: Heavy Fist   0.027247        0.140199
# Fire Eagle IPA                              0.035232        0.271452
# Peacemaker                                  0.174466        0.147916
#
# beer_name                                  Humbucker Helles
# beer_name
# Quakertown Stout                                   0.000000
# Greenbelt Farmhouse Ale                            0.000000
# Heavy Machinery IPA Series #1: Heavy Fist          0.104002
# Fire Eagle IPA                                     0.134482
# Peacemaker                                         0.109726
#
# [5 rows x 130 columns]

# %%
#Testing for Little Boss, local Austin beer
cosine_sim_series = cosine_sim_df.loc['Little Boss']

beers_simliar_to_Little_Boss = cosine_sim_series.sort_values(ascending= False)

# %%
beers_simliar_to_Little_Boss.head(15)
# Out:
# beer_name
# Little Boss                         1.000000
# Spirit Animal                       0.846100
# Professor Black                     0.742843
# Van Dayum!                          0.721066
# Pete's Wicked Summer Brew (2002)    0.358466
# Pete's Wicked Summer Brew (1996)    0.358466
# Pete's Wicked Summer Brew (1997)    0.358466
# Pete's Wicked Summer Brew (1995)    0.358466
# Pete's Wicked Pale Ale (1997)       0.357433
# Peacemaker                          0.305928
# Monarch Classic American Wheat      0.278968
# Special Release                     0.274249
# Power & Light                       0.269154
# Slow Ride                           0.233216
# Fire Eagle IPA                      0.220659
# Name: Little Boss, dtype: float64
